# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
gdown.download('https://bit.ly/3RhoNho', 'ns_202309.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3RhoNho
# To: C:\Users\user\kepco\ns_202309.csv
# 100%|█████████████████████████████████████████████████████████████████████████████| 57.6M/57.6M [00:15<00:00, 3.60MB/s]
# 'ns_202309.csv'

# %%
import pandas as pd

# %%
ns_df = pd.read_csv('ns_202309.csv', low_memory=False)
ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
#마지막열은 csv각 라인 끝에 콤마가 있어서 판다스가 자동으로 추가한 것 삭제 필요
ns_book = ns_df.loc[:, '번호':'등록일자']
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
#다른방법
ns_df.columns != 'Unnamed: 13'
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False])

# %%
selected_columns = ns_df.columns != 'Unnamed: 13'
ns_book = ns_df.loc[:, ns_df.columns != 'Unnamed: 13']
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
#pandas에서 데이터프레임의 행이나 열을 삭제하는 drop() 메서드
ns_book = ns_df.drop('Unnamed: 13', axis=1)  #axis를 1로 지정해줌으로써 열을 삭제 0을 지정해주면 행을 삭제
ns_book
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# ...

# %%
ns_book = ns_df.drop(['부가기호', 'Unnamed: 13'], axis=1)
ns_book
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN    권   주제분류번호  도서권수  대출건수        등록일자
# ...

# %%
#위의 방식들은 따로 저장하는 방식
#바로 수정도 가능
ns_book.drop('주제분류번호', axis=1, inplace=True)
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권  도서권수  대출건수        등록일자
# 0     NaN  NaN     1     0  2021-03-19
# 1     NaN  NaN     1     0  2021-03-19
# 2     NaN  NaN     1     0  2021-03-19
# 3     NaN  NaN     1     0  2021-03-19
# 4     NaN  NaN     1     0  2021-03-19

# %%
ns_df.isna() #NaN인 부분 보여줌
# Out:
#            번호    도서명     저자    출판사   발행년도   ISBN  세트 ISBN   부가기호      권  \
# 0       False  False  False  False  False  False     True   True   True
# 1       False  False  False  False  False  False     True   True   True
# 2       False  False  False  False  False  False     True   True   True
# 3       False  False  False  False  False  False     True   True   True
# 4       False  False  False  False  False  False     True   True   True
# ...       ...    ...    ...    ...    ...    ...      ...    ...    ...
# 401677  False  False  False  False  False  False    False   True  False
# 401678  False  False  False  False  False  False    False   True  False
# 401679  False  False  False  False  False  False    False   True  False
# 401680  False  False  False  False  False  False    False   True  False
# 401681  False  False  False  False  False  False    False  False  False
#
#         주제분류번호   도서권수   대출건수   등록일자  Unnamed: 13
# 0         True  False  False  False         True
# ...

# %%
ns_df.isna().sum() #NaN개수 / 불필요한 컬럼값 확인 가능
# Out:
# 번호                  0
# 도서명               403
# 저자                201
# 출판사              4795
# 발행년도               17
# ISBN                0
# 세트 ISBN        339811
# 부가기호            76648
# 권              333415
# 주제분류번호          20322
# 도서권수                0
# 대출건수                0
# 등록일자                0
# Unnamed: 13    401682
# dtype: int64

# %%
#dropna()
#pandas는 비어있는 값을 not a number // NaN로 표현
#NaN이 하나 이상 포함된 행이나 열을 삭제
ns_book = ns_df.dropna(axis=1) #모든값이 NaN인 열을 삭제하려면 how매개변수를 'all'로 지정
                               #implace=True를 지정하여 데이터프레임을 새로 생성하여 반환하지 않고 현재 데이터프레임을 수정할 수 있음
ns_book.head()
# Out:
#    번호           ISBN  도서권수  대출건수        등록일자
# 0   1  9788937444319     1     0  2021-03-19
# 1   2  9791190123969     1     0  2021-03-19
# 2   3  9788968332982     1     0  2021-03-19
# 3   4  9788970759906     1     0  2021-03-19
# 4   5  9788934990833     1     0  2021-03-19

# %%
#1. 컬럼이 na가 70%이상인 컬럼을 지우고
#2. 행이 na가 20%이상인 행을 지우고 남은 na의 갯수

# %%
ns_book = (ns_df.isna().sum() / ns_df.shape[0]) > 0.7
ns_book
# Out:
# 번호             False
# 도서명            False
# 저자             False
# 출판사            False
# 발행년도           False
# ISBN           False
# 세트 ISBN         True
# 부가기호           False
# 권               True
# 주제분류번호         False
# 도서권수           False
# 대출건수           False
# 등록일자           False
# Unnamed: 13     True
# dtype: bool

# %%
#1.컬럼이 na가 70%이상인 컬럼을 지우고
ns_book = (ns_df.isna().sum() / ns_df.shape[0]) > 0.7 #70%이상인거 찾기
remove_cols = ns_df.loc[:, ns_book != True]           #제외시키기
remove_cols.head()

#똑같음
#ns_book = (ns_df.isna().sum() / ns_df.shape[0]) > 0.7 70%이상인거 찾기
#remove_cols = ns_df.columns[ns_book]                  컬럼명만 가져오기
#ns_df.drop(columns=remove_cols, axis=1)               지우기
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   부가기호 주제분류번호  도서권수  대출건수        등록일자
# 0  NaN    NaN     1     0  2021-03-19
# 1  NaN    NaN     1     0  2021-03-19
# 2  NaN    NaN     1     0  2021-03-19
# 3  NaN    NaN     1     0  2021-03-19
# 4  NaN    NaN     1     0  2021-03-19

# %%
#2 행이 na가 20%이상인 행을 지우고 남은 na의 갯수

# %%
ns_book = (ns_df.isna().sum(axis=1) / ns_df.shape[1]) > 0.2 #
remove_row = ns_df.loc[ns_book != True, :]
remove_row.head()
# Out:
#       번호                                           도서명  \
# 60    61  (맛있는 디자인)프리미어 프로 CC: 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 67    68          프리미어 프로 & 애프터 이펙트  CC 2021 무작정 따라하기
# 107  108                                     비판기 이전 저작
# 108  109                                     비판기 이전 저작
# 109  110                                           파친코
#
#                                    저자    출판사  발행년도           ISBN  \
# 60                 정지원,심수진,윤성우,김덕영 지음  한빛미디어  2021  9791162244029
# 67                     신의철,이현석,김나현 지음     길벗  2021  9791165214739
# 107  임마누엘 칸트 지음;한국칸트학회 기획;김상현 ;이남원 옮김    한길사  2021  9788935667888
# 108  임마누엘 칸트 지음;한국칸트학회 기획;박진...[등] 옮김    한길사  2021  9788935667871
# 109                    이민진 지음 ;이미정 옮김   문학사상  2018  9788970129815
#
#            세트 ISBN 부가기호     권   주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 60             NaN    1  2021  005.567     1     1  2021-03-15          NaN
# 67             NaN    0  2021  005.567     1     0  2021-03-15          NaN
# ...

# %%
# 행삭제
ns_book = ns_df.dropna(axis=1, how='all')
ns_book2 = ns_book.drop([0,1])
ns_book2.head()
#ns_book2 = ns_book[2:]
# Out:
#    번호                                  도서명                    저자  \
# 2   3                나도 한 문장 잘 쓰면 바랄 게 없겠네                김선영 지음
# 3   4                              예루살렘 해변      이도 게펜 지음, 임재희 옮김
# 4   5                김성곤의 중국한시기행 : 장강·황하 편                김성곤 지음
# 5   6                        처음 읽는 음식의 세계사  미야자키 마사카츠 지음, 한세희 옮김
# 6   7  아르센 벵거 자서전 My Life in Red and White     아르센 벵거 지음, 이성모 옮김
#
#             출판사  발행년도           ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수  \
# 2          블랙피쉬  2021  9788968332982     NaN  NaN  NaN    NaN     1     0
# 3         문학세계사  2021  9788970759906     NaN  NaN  NaN    NaN     1     0
# 4           김영사  2021  9788934990833     NaN  NaN  NaN    NaN     1     0
# 5          탐나는책  2021  9791189550370     NaN  NaN  NaN    NaN     1     0
# 6  한즈미디어(한스미디어)  2021  9791160075793     NaN  NaN  NaN    NaN     1     0
#
#          등록일자
# 2  2021-03-19
# 3  2021-03-19
# 4  2021-03-19
# 5  2021-03-19
# 6  2021-03-19

# %%
selected_row = ns_df['출판사'] == '한빛미디어'
selected_row
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 401677    False
# 401678    False
# 401679    False
# 401680    False
# 401681    False
# Name: 출판사, Length: 401682, dtype: bool

# %%
#불리언배열
selected_row = ns_df['출판사'] == '한빛미디어'
ns_book2 = ns_book[selected_row]
ns_book2.head()
# Out:
#       번호                                                도서명  \
# 60    61       (맛있는 디자인)프리미어 프로 CC: 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 70    71         처음 배우는 애저 (Azure Portal로 배우는 애저 도입부터 활용까지)
# 88    89  맛있는 디자인 프리미어 프로 CC 2021 - 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 156  157                    실전 보고서 작성 기술 with 파워포인트, 워드, 한글
# 198  199                                    처음 배우는 리액트 네이티브
#
#                            저자    출판사  발행년도           ISBN 세트 ISBN 부가기호     권  \
# 60         정지원,심수진,윤성우,김덕영 지음  한빛미디어  2021  9791162244029     NaN    1  2021
# 70                        김도균  한빛미디어  2020  9791162243695     NaN  NaN   NaN
# 88   정지원, 심수진, 윤성우, 김덕영 (지은이)  한빛미디어  2021  9791162244029     NaN  NaN   NaN
# 156                    홍장표 지음  한빛미디어  2020  9791162243763     NaN  NaN   NaN
# 198                    김범준 지음  한빛미디어  2021  9791162243879     NaN  NaN   NaN
#
#       주제분류번호  도서권수  대출건수        등록일자
# 60   005.567     1     1  2021-03-15
# 70    005.74     1     1  2021-03-15
# ...

# %%
a = ns_book['대출건수'] > 1000
ns_book[a]
# Out:
#             번호                                      도서명                 저자  \
# 94781    94782  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문   유발 하라리 지음 ;조현욱 옮김
# 346944  346945                         해커스 토익:Listening       David Cho 지음
#
#              출판사  발행년도           ISBN 세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 94781        김영사  2016  9788934972464     NaN  NaN  NaN     909    30  1468
# 346944  해커스어학연구소  2005  9788990700148     NaN    1  NaN  740.77    29  1065
#
#               등록일자
# 94781   2016-04-22
# 346944  2005-02-01

# %%
#중복된 행
#duplicated()
#중복된행 중에서 처음 행을 제외한 나머지 행은 True로 그 외에 중복되지 않은 나머지 모든 행은 False로 표시한 불리언 배열을 반환
#sum()함수 사용시 True를 1로 인식하기 때문에 중복된 행의 개수를 셀 수 있음

sum(ns_book.duplicated()) #번호열의 고유값때문에 중복된 행 X
# Out:
# 0

# %%
#지정해준 칼럼값을 기준으로 찾을 수 있음
sum(ns_book.duplicated(subset=['도서명', '저자', 'ISBN']))
# Out:
# 22096

# %%
#keep매개 변수를 False로 지정해 중복된 모든 행을 True로 표시
#keep='first'로 지정해주면 중복값이 있으면 첫번째 값을 duplicated 여부를 False로 반환하고, 나머지 중복값에 대해서는 True를 반환하게 됩니다. keep='last'는 그 반대
dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN'], keep=False)
ns_book3 = ns_book[dup_rows]
ns_book3
# Out:
#             번호                  도서명                 저자           출판사  발행년도  \
# 109        110                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 110        111                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 111        112  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 112        113  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 113        114                 스토너   존 윌리엄스 지음 ;김승욱 옮김  RHK(알에이치코리아)  2021
# ...        ...                  ...                ...           ...   ...
# 401672  401673  미애와 루이, 318일간의 버스여행   최미애 글;장 루이 볼프 사진            자인  2003
# 401674  401675            음악이 있는 풍경             김정환 지음        이론과 실천  1998
# 401675  401676                   시귀   오노 후유미 지음;임희선 옮김            들녘  1999
# 401679  401680         (최인훈 장편소설)화두             최인훈 지음           민음사  1994
# 401681  401682           참으로 소중한 생각             김일상 지음           동문사  1995
#
# ...

# %%
#groupby()
count_df = ns_book[['도서명', '저자', 'ISBN', '권', '대출건수']]  #출력화면간단화를 위함
group_df = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False) #dropna=false - 누락된 nan도 함께 카운트
loan_count = group_df.sum()#그룹화 및 nan이 있는 행을 삭제X 및 더하기
loan_count.head()
# Out:
#                                                                                             대출건수
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    38
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    10
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     4
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     3
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     0

# %%
dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN', '권']) # 중복된 행을 True로 표시
unique_rows = ~dup_rows # False로 되어 있는 고유한 행을 불리언반전을 통해 True로 변환
ns_book3 = ns_book[unique_rows].copy()
ns_book3
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401673  401674            소설의 사회사 비교론            조동일 지음  지식산업사  2001
# 401676  401677                    큰오빠            박정근 지음  우리문학사  1998
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# ...

# %%
sum(ns_book3.duplicated(subset=['도서명', '저자', 'ISBN', '권'])) #중복된 행 확인
# Out:
# 0

# %%
#중복된데이터 합치고 다시 넣어주는 파트
ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True) #원본 데이터프레임 인덱스 설정
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN 부가기호 주제분류번호  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN  NaN    NaN
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN  NaN    NaN
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN  NaN    NaN
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN  NaN    NaN
# ...

# %%
ns_book3.update(loan_count) #원본데이터값 업데이트
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN 부가기호 주제분류번호  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN  NaN    NaN
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN  NaN    NaN
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN  NaN    NaN
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN  NaN    NaN
# ...

# %%
ns_book4 = ns_book3.reset_index()  #업데이트 후 인덱스열 해제
ns_book4.head()
# Out:
#                      도서명                저자           ISBN    권  번호    출판사  \
# 0                인공지능과 흙            김동훈 지음  9788937444319  NaN   1    민음사
# 1           가짜 행복 권하는 사회            김태형 지음  9791190123969  NaN   2   갈매나무
# 2  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음  9788968332982  NaN   3   블랙피쉬
# 3                예루살렘 해변  이도 게펜 지음, 임재희 옮김  9788970759906  NaN   4  문학세계사
# 4  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음  9788934990833  NaN   5    김영사
#
#    발행년도 세트 ISBN 부가기호 주제분류번호  도서권수  대출건수        등록일자
# 0  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 1  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 2  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 3  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 4  2021     NaN  NaN    NaN     1   0.0  2021-03-19

# %%
sum(ns_book['대출건수'] > 100)
# Out:
# 2311

# %%
sum(ns_book4['대출건수'] > 100) #중복된 도서의 대출건수를 합쳤기 때문
# Out:
# 2550

# %%
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
ns_book4.head()
# Out:
#                      도서명                저자           ISBN    권  번호    출판사  \
# 0                인공지능과 흙            김동훈 지음  9788937444319  NaN   1    민음사
# 1           가짜 행복 권하는 사회            김태형 지음  9791190123969  NaN   2   갈매나무
# 2  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음  9788968332982  NaN   3   블랙피쉬
# 3                예루살렘 해변  이도 게펜 지음, 임재희 옮김  9788970759906  NaN   4  문학세계사
# 4  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음  9788934990833  NaN   5    김영사
#
#    발행년도 세트 ISBN 부가기호 주제분류번호  도서권수  대출건수        등록일자
# 0  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 1  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 2  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 3  2021     NaN  NaN    NaN     1   0.0  2021-03-19
# 4  2021     NaN  NaN    NaN     1   0.0  2021-03-19

# %%
#여러가지 수정으로 인해 데이터프레임의 열 순서 변경 혼동하지 않기 위해 원상복구 필요
ns_book4 = ns_book4[ns_book.columns]
ns_book4.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1   0.0  2021-03-19

# %%
#저장
ns_book4.to_csv('ns_book4.csv', index=False)

# %%
#일괄처리함수만들기

# %%
def data_cleaning(filename):
    """
    남산 도서관 장서 CSV데이터 전처리 함수
    :param filename: CSV 파일 이름
    """
    #파일을 데이터프레임으로 읽기
    ns_df = pd.read_csv(filename, low_memory=False)
    #NaN인 열 삭제
    ns_book = ns_df.dropna(axis=1, how='all')
    #대출건수를 합치기 위해 필요한 행만 추출하여 count_df 데이터프레임 생성
    count_df = ns_book[['도서명', '저자', 'ISBN', '권', '대출건수']]
    #도서명, 저자, ISBN, 권을 기준으로 대출건수를 groupby
    loan_count = count_df.groupby(by=['도서명', '저자', 'ISBN', '권'], dropna=False).sum()
    #원본 데이터프레임에서 중복된 행을 제외하고 고유한 행만 추출하여 복사
    dup_rows = ns_book.duplicated(subset=['도서명', '저자', 'ISBN', '권'])
    unique_rows = ~dup_rows
    ns_book3 = ns_book[unique_rows].copy()
    #도서명, 저자, ISBN, 권을 인덱스로 설정
    ns_book3.set_index(['도서명', '저자', 'ISBN', '권'], inplace=True)
    #loan_count에 저장된 누적 대출건수를 업데이트
    ns_book3.update(loan_count)
    #인덱스 재설정
    ns_book4 = ns_book3.reset_index()
    #원본 데이터프레임의 열 순서로 변경
    ns_book4 = ns_book4[ns_book.columns]
    return ns_book4

# %%
new_ns_book4 = data_cleaning('ns_202309.csv')
ns_book4.equals(new_ns_book4)
# Out:
# True

# %%
#데이터프레임 정보요약확인

# %%
import pandas as pd
ns_book4 = pd.read_csv('ns_book4.csv', low_memory=False)
ns_book4.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1   0.0  2021-03-19

# %%
ns_book4.info() #열마다 NaN값이 얼마나 들어있는지 확인
#정확한 메모리 사용량을 알기 위해서는 memory_usage 매개변수에 'deep'옵션을 지정
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384591 entries, 0 to 384590
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   번호       384591 non-null  int64
#  1   도서명      384188 non-null  object
#  2   저자       384393 non-null  object
#  3   출판사      379950 non-null  object
#  4   발행년도     384577 non-null  object
#  5   ISBN     384591 non-null  object
#  6   세트 ISBN  56576 non-null   object
#  7   부가기호     310386 non-null  object
#  8   권        63378 non-null   object
#  9   주제분류번호   364727 non-null  object
#  10  도서권수     384591 non-null  int64
#  11  대출건수     384591 non-null  float64
#  12  등록일자     384591 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 38.1+ MB

# %%
#누락된 값 처리
#누락된 값 개수 확인 : isna()
p = pd.DataFrame(ns_book4)
p.isna()
# Out:
#            번호    도서명     저자    출판사   발행년도   ISBN  세트 ISBN  부가기호      권  \
# 0       False  False  False  False  False  False     True  True   True
# 1       False  False  False  False  False  False     True  True   True
# 2       False  False  False  False  False  False     True  True   True
# 3       False  False  False  False  False  False     True  True   True
# 4       False  False  False  False  False  False     True  True   True
# ...       ...    ...    ...    ...    ...    ...      ...   ...    ...
# 384586  False  False  False  False  False  False    False  True  False
# 384587  False  False  False  False  False  False    False  True  False
# 384588  False  False  False  False  False  False    False  True  False
# 384589  False  False  False  False  False  False    False  True  False
# 384590  False  False  False  False  False  False    False  True  False
#
#         주제분류번호   도서권수   대출건수   등록일자
# 0         True  False  False  False
# 1         True  False  False  False
# ...

# %%
ns_book4.isna().sum()  #반대 : notna() - 누락되지 않은 값을 확인
# Out:
# 번호              0
# 도서명           403
# 저자            198
# 출판사          4641
# 발행년도           14
# ISBN            0
# 세트 ISBN    328015
# 부가기호        74205
# 권          321213
# 주제분류번호      19864
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %%
#누락된 값으로 표시 : None / np.nan
#도서권수가 누락된 값이 없으므로 첫번째 행값을 None으로 바꾼후 적용(정수형 열에 적용 가능)
ns_book4.loc[0, '도서권수'] = None
ns_book4['도서권수'].isna().sum()
# Out:
# 1

# %%
ns_book4.head(2) #Nan를 특별한 실수값으로 취급하기 때문에 도서권수가 1에서 1.0으로 int64가 float64로 변경됨
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN   NaN   0.0  2021-03-19
# 1    NaN   1.0   0.0  2021-03-19

# %%
#원래 데이터 집어넣고 데이터타입 변경하기
ns_book4.loc[0, '도서권수'] = 1
ns_book4 = ns_book4.astype({'도서권수' : 'int64', '대출건수' : 'int64'})
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %%
#문자형 열에는 적용 불가능한 None
ns_book4.loc[0, '부가기호'] = None
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN  부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  None  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN   NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %%
#np.nan으로 해결
import numpy as np
ns_book4.loc[0, '부가기호'] = np.nan
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %%
#누락된 값 변경
#'세트ISBN'열 대부분 비어있음. 누락된 값을 NaN가 아닌 빈 문자열('')로 변경
#loc() - 누락된 값을 원하는 값으로 변경 가능

set_isbn_na_rows = ns_book4['세트 ISBN'].isna() #누락된 값을 찾아 boolean배열로 반환
ns_book4.loc[set_isbn_na_rows, '세트 ISBN'] = ''#누락된 값을 빈 문자열로 변경
ns_book4['세트 ISBN'].isna().sum()              #누락된 값 개수 세기
# Out:
# 0

# %%
#fillna()를 통해 더욱 쉽게 누락된 값 변경 가능
ns_book4.fillna('없음').isna().sum()
# Out:
# 번호         0
# 도서명        0
# 저자         0
# 출판사        0
# 발행년도       0
# ISBN       0
# 세트 ISBN    0
# 부가기호       0
# 권          0
# 주제분류번호     0
# 도서권수       0
# 대출건수       0
# 등록일자       0
# dtype: int64

# %%
#ns_book4에 컬럼값을 지정해줌으로써 특정 열만 선택해서 바꿀수도 있음
ns_book4['부가기호'].fillna('없음').isna().sum()
#열이름 없이 개수만있는 판다스 시리즈 객체로 반환
# Out:
# 0

# %%
#특정열의 NaN를 바꾸면서 전체 데이터프레임을 반환하려면 딕셔너리를 전달하면 됨
ns_book4.fillna({'부가기호':'없음'}).isna().sum()
# Out:
# 번호              0
# 도서명           403
# 저자            198
# 출판사          4641
# 발행년도           14
# ISBN            0
# 세트 ISBN         0
# 부가기호            0
# 권          321213
# 주제분류번호      19864
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64
